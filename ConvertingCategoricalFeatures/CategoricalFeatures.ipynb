# %% [markdown]
# # Converting Categorical Features

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Get the Data

# %%
titanic = pd.read_csv('D:\\P Y T H O N\\Machine Learning\\ConvertingCategoricalFeatures\\titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
Sex = pd.get_dummies(titanic['Sex'])
Sex
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# ..      ...   ...
# 886       0     1
# 887       1     0
# 888       1     0
# 889       0     1
# 890       0     1
#
# [891 rows x 2 columns]

# %%
Sex = pd.get_dummies(titanic['Sex'], drop_first=True)
Sex
# Out:
#      male
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
# ..    ...
# 886     1
# 887     0
# 888     0
# 889     1
# 890     1
#
# [891 rows x 1 columns]

# %%
titanic['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
titanic.dropna(inplace=True)

# %%
titanic['Embarked'].unique()
# Out:
# array(['C', 'S', 'Q'], dtype=object)

# %%
Embarkes = pd.get_dummies(titanic['Embarked'], drop_first=True)
Embarkes
# Out:
#      Q  S
# 1    0  0
# 3    0  1
# 6    0  1
# 10   0  1
# 11   0  1
# ..  .. ..
# 871  0  1
# 872  0  1
# 879  0  0
# 887  0  1
# 889  0  0
#
# [183 rows x 2 columns]

# %%
titanic.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
titanic.drop(['PassengerId','Name','Ticket','Sex','Embarked'], axis=1, inplace=True)
titanic.head()
# Out:
#     Survived  Pclass   Age  SibSp  Parch     Fare Cabin
# 1          1       1  38.0      1      0  71.2833   C85
# 3          1       1  35.0      1      0  53.1000  C123
# 6          0       1  54.0      0      0  51.8625   E46
# 10         1       3   4.0      1      1  16.7000    G6
# 11         1       1  58.0      0      0  26.5500  C103

# %%
titanic = pd.concat([titanic, Sex, Embarkes], axis=1)
titanic.head()
# Out:
#     Survived  Pclass   Age  SibSp  Parch     Fare Cabin  male    Q    S
# 1        1.0     1.0  38.0    1.0    0.0  71.2833   C85     0  0.0  0.0
# 3        1.0     1.0  35.0    1.0    0.0  53.1000  C123     0  0.0  1.0
# 6        0.0     1.0  54.0    0.0    0.0  51.8625   E46     1  0.0  1.0
# 10       1.0     3.0   4.0    1.0    1.0  16.7000    G6     0  0.0  1.0
# 11       1.0     1.0  58.0    0.0    0.0  26.5500  C103     0  0.0  1.0
